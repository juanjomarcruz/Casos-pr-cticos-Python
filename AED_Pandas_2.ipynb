# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#We use the pandas read_csv() method in order to read the csv file located in the indicated path ad we store it in the dataframe variable df. Then we use the head(10) method to print the first 10 lines of our dataframe.
df=pd.read_csv('C:/Users/juanj/Desktop/ThePower Business School/Documentación - Python y SQL/BostonHousing.csv')
df.head(10)
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %%
print(df.shape)
df.count()
# Out:
# (506, 14)
# crim       506
# zn         506
# indus      506
# chas       506
# nox        506
# rm         506
# age        506
# dis        506
# rad        506
# tax        506
# ptratio    506
# b          506
# lstat      506
# medv       506
# dtype: int64

# %%
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.count() #comprobamos que ninguna columna tiene valores nulos, es decir, no hay celdas vacías, porque se han contado 506 celdas no vacías en cada columna y el shape nos ha dado el tamaño del dataframe: 506 filas y 14 columnas.
# Out:
# crim       506
# zn         506
# indus      506
# chas       506
# nox        506
# rm         506
# age        506
# dis        506
# rad        506
# tax        506
# ptratio    506
# b          506
# lstat      506
# medv       506
# dtype: int64

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
sns.distplot(x=df['crim'],kde=False)
plt.xlabel('Crime Rate Per Capita')
plt.ylabel('Count')
# Out:
# C:\Users\juanj\AppData\Local\Temp\ipykernel_13116\4219609109.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['crim'],kde=False)
# Text(0, 0.5, 'Count')

# %%
sns.distplot(x=df['zn'],kde=False)
plt.xlabel('Residential Land Ratio for Lots Over 25,000 Square Feet')
plt.ylabel('Count')
# Out:
# C:\Users\juanj\AppData\Local\Temp\ipykernel_13116\3819635372.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['zn'],kde=False)
# Text(0, 0.5, 'Count')

# %%
sns.boxplot(df['crim'])
# Out:
# <Axes: ylabel='crim'>

# %%
sns.displot(x=df['indus'],kde=True)
plt.xlabel('Proportion of non-retail business acres by city')
plt.ylabel('Count')
# Out:
# Text(5.069444444444445, 0.5, 'Count')

# %%
df['industrialized'] = (df['indus'] >= 15).astype(int)

# %%
sns.displot(x='medv', data=df,kde=True)

# %%
from scipy import stats
res=stats.kstest(df['rm'],'norm')
res.statistic
res.pvalue
# Out:
# 0.0

# %%
sns.catplot(x='industrialized',y='medv',data=df,kind='box')
plt.xlabel(None)
plt.xticks(np.arange(2),['Non-Industrialized','Industrialized'])
plt.ylabel('MEDV')
# Out:
# Text(30.375617283950618, 0.5, 'MEDV')

# %%
sns.catplot(x='industralized',y='medv',data=df, kind='strip')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sns.catplot(x='industralized',y='medv',data=df, kind='strip')
#
# File c:\Users\juanj\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:2782, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2779     elif x is not None and y is not None:
#    2780         raise ValueError("Cannot pass values for both `x` and `y`.")
# -> 2782 p = Plotter(
#    2783     data=data,
#    2784     variables=dict(
#    2785         x=x, y=y, hue=hue, row=row, col=col, units=units, weight=weights
#    2786     ),
# ...

# %%
sns.displot(df['medv'])

# %%
sns.displot(x=df['nox'],kde=True)
plt.xlabel('Nitric Oxides Concentration')
plt.ylabel('Count')
# Out:
# Text(5.069444444444445, 0.5, 'Count')

# %%
sns.boxplot(x='nox',data=df,showmeans=True)
plt.xlabel('Nitric Oxide Concentration')
# Out:
# Text(0.5, 0, 'Nitric Oxide Concentration')

# %%
sns.regplot(x='crim',y='medv',data=df)
plt.xlabel('Tasa de criminalidad')
plt.ylabel('Valor medio de la vivienda (Miles de dólares)')
# Out:
# Text(0, 0.5, 'Valor medio de la vivienda (Miles de dólares)')

# %%
sns.regplot(x='zn',y='medv',data=df)
plt.xlabel('Proporción de terreno residencial')
plt.ylabel('Valor medio de la vivienda (Miles de dólares)')
# Out:
# Text(0, 0.5, 'Valor medio de la vivienda (Miles de dólares)')

# %%
sns.catplot(x='chas',y='medv',data=df)
plt.xlabel('Variable ficticia Charles River')
plt.ylabel('Valor medio (Miles de dólares)')
# Out:
# Text(30.375617283950618, 0.5, 'Valor medio (Miles de dólares)')

# %%
sns.regplot(x='indus',y='medv',data=df)
plt.xlabel('Proportion of non-retail business acres by city')
plt.ylabel('MEDV')
# Out:
# Text(0, 0.5, 'MEDV')

# %%
sns.scatterplot(x='nox',y='medv',data=df)
plt.xlabel('Concentración de Óxidos Nítricos')
plt.ylabel('Valor medio (Miles de dólares)')
# Out:
# Text(0, 0.5, 'Valor medio (Miles de dólares)')

# %%
sns.regplot(x='rm',y='medv',data=df)
plt.xlabel('Número de habitaciones')
plt.ylabel('Valor medio (Miles de dólares)')
# Out:
# Text(0, 0.5, 'Valor medio (Miles de dólares)')

# %%
sns.displot(x='age',data=df)
plt.xlabel('Proportion of owner-occupied units built before 1940')
# Out:
# Text(0.5, 9.444444444444438, 'Proportion of owner-occupied units built before 1940')

# %%
sns.displot(x='dis',data=df,kde=True)
plt.xlabel('Weighted Distance to Five Boston Employment Centers')
plt.ylabel('Count')
# Out:
# Text(5.069444444444445, 0.5, 'Count')

# %%
sns.displot(x='rad',data=df,kde=True)
plt.xlabel('Radial Road Accessibility Index')
plt.ylabel('Count')
# Out:
# Text(5.069444444444445, 0.5, 'Count')

# %%
sns.displot(x='tax',data=df,kde=True)
plt.xlabel('Property taxes per $10,000 property value')
plt.ylabel('Count')
# Out:
# Text(5.069444444444445, 0.5, 'Count')

# %%
sd=np.std(df['tax'])/np.mean(df['tax'])*100
print(sd)
# Out:
# 41.24330510530522

# %%
df['High Property Tax Rate']=(df['tax']>500).astype(int)

# %%
sns.catplot(x='High Property Tax Rate',y='medv',data=df)
plt.xlabel('High Property Tax Rate')
plt.ylabel('MEDV')
# Out:
# Text(30.375617283950618, 0.5, 'MEDV')

# %%
df['Radial Highway Accesible']=(df['rad']>20).astype(int)

# %%
sns.catplot(x='Radial Highway Accesible', y='medv',data=df)

# %%
sns.scatterplot(x='rad',y='medv',data=df)
plt.xlabel('Índice de accesibilidad a carreteras radiales')
plt.ylabel('Valor medio (Miles de dólares)')
# Out:
# Text(0, 0.5, 'Valor medio (Miles de dólares)')

# %%
sns.scatterplot(x='tax',y='medv',data=df)
plt.xlabel('Tasa de impuestos por $10,000')
plt.ylabel('Valor medio (Miles de dólares)')
# Out:
# Text(0, 0.5, 'Valor medio (Miles de dólares)')

# %%
sns.displot(x='b',data=df, kde=True)
plt.xlabel('Proportion of people with African American descent')
# Out:
# Text(0.5, 9.444444444444438, 'Proportion of people with African American descent')

# %%
sns.displot(x='lstat',data=df, kde=True)
plt.xlabel('Low Status Population (%)')
# Out:
# Text(0.5, 9.444444444444438, 'Low Status Population (%)')

# %%
sns.scatterplot(x='ptratio',y='medv',data=df)
plt.xlabel('Proporción de alumnos por maestro')
plt.ylabel('Valor medio de la vivienda')
# Out:
# Text(0, 0.5, 'Valor medio de la vivienda')

# %%
sns.scatterplot(x='b',y='medv',data=df)
plt.xlabel('Proporción de personas con ascendencia afroamericana')
plt.ylabel('Valor medio (Miles de dólares)')
# Out:
# Text(0, 0.5, 'Valor medio (Miles de dólares)')

# %%
sns.regplot(x='lstat',y='medv',data=df)
plt.xlabel('Proporción de personas de estatus bajo')
plt.ylabel('Valor medio (Miles de dólares)')
# Out:
# Text(0, 0.5, 'Valor medio (Miles de dólares)')

# %%
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix,annot=True,fmt='.1f',cmap='coolwarm',linewidths=.5)
# Out:
# <Axes: >

# %%
sns.regplot(x='rad',y='tax',data=df)
plt.xlabel('Índice de accesibilidad a carreteras radiales')
plt.ylabel('Tasa de impuestos a la propiedad')
# Out:
# Text(0, 0.5, 'Tasa de impuestos a la propiedad')

# %%
sns.displot(x=df['rm'],kde=True)
plt.xlabel('Average number of rooms per home')
plt.ylabel('Count')
# Out:
# Text(13.819444444444445, 0.5, 'Count')

# %%
from scipy import stats
result=stats.shapiro(df['rm'])
result.statistic
result.pvalue
print('Test statistic:',result.statistic)
print('P-value:','{:e}'.format(result.pvalue))
# Out:
# Test statistic: 0.9608722575483464
# P-value: 2.411977e-10

# %%
result=stats.kstest(df['rm'],'norm')
result.statistic
result.pvalue
print('D statistic:',result.statistic)
print('P-value:','{:e}'.format(result.pvalue))
# Out:
# D statistic: 0.9998152774582629
# P-value: 0.000000e+00

# %%
result=stats.anderson(df['rm'],'norm')
print("Critical Values:", result.critical_values)
print("Anderson-Darling Test Statistic:", result.statistic)
print("Significance Levels:", result.significance_level)
# Out:
# Critical Values: [0.572 0.651 0.781 0.911 1.084]
# Anderson-Darling Test Statistic: 6.1177220513370685
# Significance Levels: [15.  10.   5.   2.5  1. ]

# %%
stats.probplot(df['rm'], dist="norm", plot=plt)
plt.title('Q-Q Plot')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.show()
